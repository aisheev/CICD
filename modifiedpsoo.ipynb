# %%
import numpy as np

def sphere(x):
    return np.sum(x**2)

def rosenbrock(x):
    return sum(100 * (x[i+1] - x[i]**2)**2 + (1 - x[i])**2 for i in range(len(x)-1))

def step_2(x):
    return np.sum(np.floor(x + 0.5)**2)

# Add more functions following the pattern above...
def quartic(x):
    return np.sum(7 * x**4 - 10 * x**3 + 5 * x**2)

def schwefel_2_21(x):
    return np.sum(abs(x) + np.prod(abs(np.sin(x))))

def schwefel_2_22(x):
    return -np.sum(np.sin(np.sqrt(abs(x))))


def foxholes(x):
    return np.sum(
      np.exp(-0.2 * np.sqrt(np.mean(x ** 2, axis=0))) + np.exp(np.sin(np.sqrt(np.mean(x ** 2, axis=0)))) + 0.1 *
    x.shape[0])

def kowalik(x):
    return np.sum([i * (x[j] - 1)**2 + (1 - x[j])**2 for j in range(len(x)) for i in range(1, 6)])

# Six-hump camel back Function
def six_hump_camel_back(x):
    return 4 * x[0]**2 - 2.1 * x[0]**4 + 1/3 * x[0]**6 + x[0] * x[1] - 4 * x[1]**2 + 4 * x[1]**4


# # Hartman 6 Function
# def hartman_6(x):
#     return -np.sum(np.array([0.3979, 0.4899, 0.6759, 0.7699, 0.9149, 1.0472]) * np.exp(-np.sum(np.array([1, 10, 100, 1000, 10000, 100000]) * ((x - np.array([0.1312, 0.2329, 0.5358, 0.8775, 0.9991, 0.7743]))**2), axis=1)))

# Levi Function N.13
def levi_n13(x):
    return np.sum(np.sin(np.sqrt(abs(x**2 + (1 + np.sin(10 * np.pi * x))**2))))

# Rastrigin Function
def rastrigin(x):
    return np.sum(x**2 - 10 * np.cos(2 * np.pi * x) + 10)

# Griewank Function
def griewank(x):
    return np.sum(x**2 / 4000 - np.cos(x) + 1)

# Ackley 1 Function
def ackley_1(x):
    return -20 * np.exp(-0.2 * np.sqrt(np.mean(x**2))) - np.exp(np.mean(np.cos(2 * np.pi * x))) + 20 + np.e


# def hartman_3(x):
#     x = np.atleast_2d(x)  # Ensure x is a 2D array for proper broadcasting
#     weights = np.array([0.3689, 0.4699, 1.0472, 1.5701, 0.7473])[:x.shape[1]]
#     return -np.sum(weights * np.exp(-np.sum(np.array([1, 10, 100, 1000]) * (x.T - np.array([0.1312, 0.2329, 0.5358, 0.8775]))**2, axis=1)))
def schwefel_2_26(x):
    return np.sum(np.abs(x) + np.sin(x**2))
def branin_rcos(x):
    return (x[1] - 5.1 / (4 * np.pi**2) * x[0]**2 + 5 * x[0] / np.pi - 6)**2 + 10 * (1 - 1 / (8 * np.pi)) * np.cos(x[0]) + 10
def goldstein_price(x):
    return (1 + (x[0] + x[1] + 1)**2 * (19 - 14 * x[0] + 3 * x[0]**2 - 14 * x[1] + 6 * x[0] * x[1] + 3 * x[1]**2)) * \
           (30 + (2 * x[0] - 3 * x[1])**2 * (18 - 32 * x[0] + 12 * x[0]**2 + 48 * x[1] - 36 * x[0] * x[1] + 27 * x[1]**2))

def penalized_1(x):
    term1 = 10 * np.sin(np.pi * x[0])**2
    term2 = sum((x[i] - 1)**2 * (1 + 10 * np.sin(np.pi * x[i] + 1)**2) for i in range(1, len(x)))
    term3 = (x[-1] - 1)**2 * (1 + np.sin(2 * np.pi * x[-1])**2)
    return term1 + term2 + term3

# def shekel_1(x):
#     a = np.array([[4, 4, 4, 4],
#                   [1, 1, 1, 1],
#                   [8, 8, 8, 8],
#                   [6, 6, 6, 6],
#                   [3, 7, 3, 7]])
#
#     b = np.array([0.1, 0.2, 0.2, 0.4, 0.4])
#
#     x = np.atleast_2d(x)  # Ensure x is a 2D array for proper broadcasting
#     return -np.sum((1 / (np.sum((x[:, np.newaxis, :] - a)**2, axis=-1) + b)), axis=-1)
#


# def shekel_2(x):
#     a = np.array([[4, 4, 4, 4],
#                   [1, 1, 1, 1],
#                   [8, 8, 8, 8],
#                   [6, 6, 6, 6],
#                   [3, 7, 3, 7]])
#
#     b = np.array([0.1, 0.2, 0.2, 0.4, 0.4])
#
#     return -np.sum((1 / (np.sum((x - a)**2, axis=1) + b))**2)
#
# def shekel_3(x):
#     a = np.array([[4, 4, 4, 4],
#                   [1, 1, 1, 1],
#                   [8, 8, 8, 8],
#                   [6, 6, 6, 6],
#                   [3, 7, 3, 7]])
#
#     b = np.array([0.1, 0.2, 0.2, 0.4, 0.4])
#
#     return -np.sum(np.sqrt(1 / (np.sum((x - a)**2, axis=1) + b)))

# Enhanced PSO Implementation

# Adaptive inertia weight calculation
def adaptive_inertia_weight(iteration, max_iter, w_max=0.9, w_min=0.4):
    return w_max - (iteration / max_iter) * (w_max - w_min)

# Check for convergence (optional, based on problem specifics)
def has_converged(previous_best, current_best, threshold=1e-6):
    return np.abs(previous_best - current_best) < threshold

# Enhanced PSO Implementation
def run_optimized_pso(obj_func, n_particles=30, n_dimensions=2, max_iter=100, bounds=(-10, 10)):
    particles = np.random.uniform(bounds[0], bounds[1], (n_particles, n_dimensions))
    velocity = np.zeros((n_particles, n_dimensions))
    pbest = np.copy(particles)
    pbest_values = np.array([obj_func(x) for x in particles])
    gbest = particles[np.argmin(pbest_values)]
    gbest_value = np.min(pbest_values)
    
    v_max = (bounds[1] - bounds[0]) / 2  # Adjust velocity clamping based on bounds
    
    previous_best = float('inf')

    for t in range(max_iter):
        w = adaptive_inertia_weight(t, max_iter)
        
        for i in range(n_particles):
            r1, r2 = np.random.rand(2)
            velocity[i] = w * velocity[i] + \
                          2.05 * r1 * (pbest[i] - particles[i]) + \
                          2.05 * r2 * (gbest - particles[i])
            velocity[i] = np.clip(velocity[i], -v_max, v_max)  # Apply velocity clamping
            
            particles[i] += velocity[i]
            particles[i] = np.clip(particles[i], bounds[0], bounds[1])  # Boundary condition handling
            
            current_value = obj_func(particles[i])
            if current_value < pbest_values[i]:
                pbest[i] = particles[i]
                pbest_values[i] = current_value
                
                if current_value < gbest_value:
                    gbest = particles[i]
                    gbest_value = current_value

        # Optional: check for convergence to stop early
        if has_converged(previous_best, gbest_value):
            print(f"Converged at iteration {t}.")
            break
        previous_best = gbest_value

    return gbest, gbest_value

functions = {
    'Sphere': sphere,
    'Rosenbrock': rosenbrock,
    'Step 2': step_2,
    'Quartic': quartic,
    'Schwefel 2.21': schwefel_2_21,
    'Schwefel 2.22': schwefel_2_22,
    'Foxholes': foxholes,
    'Kowalik':kowalik,
    'Six_hump_camel_back':six_hump_camel_back,
    # 'hartman_3':hartman_3,
    # 'hartman_6':hartman_6,
    'levi_n13':levi_n13,
    'rastrigin':rastrigin,
    'griewank':griewank,
    'ackley_1':ackley_1,
    'schwefel_2_26':schwefel_2_26,
    'branin_rcos':branin_rcos,
    'goldstein_price':goldstein_price,
    'penalized_1':penalized_1,
    # 'shekel_1':shekel_1,
    # 'shekel_2':shekel_2,
    # 'shekel_3':shekel_3

}


# Run the optimized PSO
for name,func in functions.items():
    gbest, gbest_value = run_optimized_pso(func)
    print(f"Benchmark Function: {name}, Optimized PSO - Best Position: {gbest}, Best Value: {gbest_value}")
# Out:
# Converged at iteration 1.
# Benchmark Function: Sphere, Optimized PSO - Best Position: [ 4.84158151 -2.55231107], Best Value: 0.567163432921198
# Converged at iteration 1.
# Benchmark Function: Rosenbrock, Optimized PSO - Best Position: [1.36379363 9.38486924], Best Value: 7.256573080752228
# Converged at iteration 1.
# Benchmark Function: Step 2, Optimized PSO - Best Position: [-10.          -3.62213842], Best Value: 1.0
# Converged at iteration 1.
# Benchmark Function: Quartic, Optimized PSO - Best Position: [2.00395043 6.00049576], Best Value: 0.6094240206434083
# Converged at iteration 1.
# Benchmark Function: Schwefel 2.21, Optimized PSO - Best Position: [ 5.74027374 -4.07492067], Best Value: 1.3127115219634193
# Converged at iteration 2.
# Benchmark Function: Schwefel 2.22, Optimized PSO - Best Position: [0.68929153 2.24714817], Best Value: -1.9990880109053664
# Converged at iteration 3.
# Benchmark Function: Foxholes, Optimized PSO - Best Position: [ 10. -10.], Best Value: 0.915744945283854
# Converged at iteration 1.
# Benchmark Function: Kowalik, Optimized PSO - Best Position: [ 6.29912076 10.        ], Best Value: 0.09567522992412998
# Converged at iteration 2.
# Benchmark Function: Six_hump_camel_back, Optimized PSO - Best Position: [-3.82840241 -3.46364197], Best Value: -0.6490737374031683
# Converged at iteration 2.
# Benchmark Function: levi_n13, Optimized PSO - Best Position: [6.06756627 5.30531044], Best Value: -1.6081254884547769
# Converged at iteration 1.
# Benchmark Function: rastrigin, Optimized PSO - Best Position: [-1.0066903   0.53554217], Best Value: 4.104726228176768
# Converged at iteration 1.
# Benchmark Function: griewank, Optimized PSO - Best Position: [ 6.0458649  -4.73037771], Best Value: 0.010617900480230036
# Converged at iteration 1.
# Benchmark Function: ackley_1, Optimized PSO - Best Position: [ 0.981965   -0.36940335], Best Value: 2.742389158019091
# Converged at iteration 1.
# Benchmark Function: schwefel_2_26, Optimized PSO - Best Position: [-9.01204982  9.66538123], Best Value: 1.271002719763727
# Converged at iteration 1.
# Benchmark Function: branin_rcos, Optimized PSO - Best Position: [9.87947494 2.91592354], Best Value: 1.3744586865692696
# Converged at iteration 3.
# Benchmark Function: goldstein_price, Optimized PSO - Best Position: [-2.4930255  6.7060856], Best Value: 115.20518427889475
# Converged at iteration 3.
# Benchmark Function: penalized_1, Optimized PSO - Best Position: [-6.03798691  2.13187467], Best Value: 0.003580672073154695
